# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('df_dummies.csv')

# %%
df = df.drop(columns=['Unnamed: 0'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162351 entries, 0 to 162350
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Month       162351 non-null  int64
#  1   DayofMonth  162351 non-null  int64
#  2   ArrTime     162351 non-null  int64
#  3   DepDelay    162351 non-null  int64
#  4   Distance    162351 non-null  int64
#  5   DayofWeek   162351 non-null  int64
#  6   Dest_ATL    162351 non-null  int64
#  7   Dest_DEN    162351 non-null  int64
#  8   Dest_DFW    162351 non-null  int64
#  9   Dest_LAX    162351 non-null  int64
#  10  Dest_ORD    162351 non-null  int64
# dtypes: int64(11)
# memory usage: 13.6 MB

# %%
df_col = list(df.columns)
df_0 = df[df_col]

# %%
df_0.hist(figsize  = [8, 8], bins='auto');

# %%
df['at_log'] = np.log10(df['ArrTime'], where=True)
# Out:
# C:\Users\Family\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)

# %%
df.at_log.describe()
# Out:
# count    162351.000000
# mean          3.149673
# std           0.339442
# min           0.000000
# 25%           3.117603
# 50%           3.230449
# 75%           3.288696
# max           3.380211
# Name: at_log, dtype: float64

# %%
sns.histplot(df, x='at_log');

# %%
df['dist_log'] = np.log10(df['Distance'], where=True)

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)

# %%
df.at_log.describe()
# Out:
# count    162351.000000
# mean          3.149673
# std           0.339442
# min           0.000000
# 25%           3.117603
# 50%           3.230449
# 75%           3.288696
# max           3.380211
# Name: at_log, dtype: float64

# %%
sns.histplot(df, x='dist_log');

# %%
df = df.drop(columns=['ArrTime', 'Distance'], axis=1)

# %%
df.to_csv('df_log.csv')
